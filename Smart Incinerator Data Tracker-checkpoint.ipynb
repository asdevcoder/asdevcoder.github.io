# %%
name= 'Anehita'
age= 25
height= 12.7
likes_python= True

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}")
print(f"Do you like Python: {likes_python}")

print(type(name))
print(type(age))
print(type(height))
print(type(likes_python))

# Ask for input
name= input("Enter your name")
age = int(input("Enter your age"))

# Check the age category
if age <18:
    print(f"Hello {name}, You are a minor")
elif age >= 18 and age <=  59:
    print(f"Hello {name}, You are an adult")
else:
    print(f"Hello {name}, You are a Senior citizen")
    
# Print a greeting
print(f"Congratulations {name}, you will be {age+ 1} year old next year")
# Out:
# Name: Anehita
# Age: 25
# Height: 12.7
# Do you like Python: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Enter your name Anehita
# Enter your age 70
# Hello Anehita, You are a Senior citizen
# Congratulations Anehita, you will be 71 year old next year
